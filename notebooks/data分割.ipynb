# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
data=pd.read_csv('Training.csv')


# 'fluid_overload' 都為0，Unnamed: 133 都 NA
data = data.drop(['fluid_overload','Unnamed: 133'],axis=1)

#刪除 相關係數=1.0
data = data.drop(['throat_irritation','redness_of_eyes','sinus_pressure','runny_nose','enlarged_thyroid','enlarged_thyroid',
                  'brittle_nails','congestion','increased_appetite','receiving_blood_transfusion','coma','slurred_speech']
                 ,axis=1)
#刪除 相關係數=0.9
data = data.drop(['weight_gain','pain_during_bowel_movements','pain_in_anal_region','bloody_stool','cramps','bruising','swollen_legs',
                 'cold_hands_and_feets','puffy_face_and_eyes','anxiety','knee_pain','spinning_movements','bladder_discomfort',
                  'passage_of_gases','weakness_of_one_body_side','toxic_look_(typhos)','mood_swings','irregular_sugar_level',
                  'yellow_urine','acute_liver_failure','swelling_of_stomach','distention_of_abdomen', 'history_of_alcohol_consumption',
                  'blister','red_sore_around_nose','small_dents_in_nails','silver_like_dusting','swollen_blood_vessels',
                  'drying_and_tingling_lips','swelling_joints','skin_peeling'],axis=1)
#刪除 0.9 以上
data = data.drop(['patches_in_throat','foul_smell_of urine','blackheads'],axis=1)

#sum()
data = data.drop(['pus_filled_pimples','unsteadiness','chest_pain','vomiting'],axis=1)
data.shape
# Out:
# (4920, 83)

# %%
test=pd.DataFrame()
for i in set(data['prognosis']):
    data1=data[data['prognosis']==i].sample(n=36)
    test=pd.concat([test,data1],axis=0)

data=data.drop(test.index,axis=0)
test=test.sample(n=1476)
# Out:
#       itching  skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# 474         0          0                     0                    0
# 1279        1          1                     0                    0
# 3166        0          0                     0                    0
# 790         0          0                     0                    0
# 1756        0          0                     0                    0
# ...       ...        ...                   ...                  ...
# 4719        1          1                     0                    0
# 1509        0          0                     0                    0
# 1851        0          0                     0                    0
# 748         0          0                     0                    0
# 2019        0          1                     0                    0
#
#       shivering  chills  joint_pain  stomach_pain  acidity  ulcers_on_tongue  \
# 474           0       0           0             0        0                 0
# 1279          0       0           0             1        0                 0
# 3166          0       0           0             0        0                 0
# 790           0       0           0             0        0                 0
# 1756          0       0           0             0        1                 0
# ...         ...     ...         ...           ...      ...               ...
# 4719          0       0           0             1        0                 0
# 1509          0       1           0             0        0                 0
# 1851          0       0           0             0        0                 0
# 748           0       0           0             0        0                 0
# 2019          0       0           0             0        0                 0
#
#       ...  stomach_bleeding  fluid_overload.1  blood_in_sputum  \
# 474   ...                 0                 0                0
# 1279  ...                 0                 0                0
# 3166  ...                 0                 0                0
# 790   ...                 0                 0                0
# 1756  ...                 0                 0                0
# ...   ...               ...               ...              ...
# 4719  ...                 0                 0                0
# 1509  ...                 0                 0                0
# 1851  ...                 0                 0                0
# 748   ...                 0                 0                0
# 2019  ...                 0                 0                0
#
#       prominent_veins_on_calf  palpitations  painful_walking  scurring  \
# 474                         0             0                0         0
# 1279                        0             0                0         0
# 3166                        0             0                0         0
# 790                         0             0                0         0
# 1756                        0             0                0         0
# ...                       ...           ...              ...       ...
# 4719                        0             0                0         0
# 1509                        0             0                0         0
# 1851                        0             0                0         0
# 748                         0             1                0         0
# 2019                        0             0                0         1
#
#       inflammatory_nails  yellow_crust_ooze                prognosis
# 474                    0                  0                     AIDS
# 1279                   0                  0            Drug Reaction
# 3166                   0                  0         Bronchial Asthma
# 790                    0                  0  Urinary tract infection
# 1756                   0                  0                 Migraine
# ...                  ...                ...                      ...
# 4719                   0                  0            Drug Reaction
# 1509                   0                  0                Pneumonia
# 1851                   0                  0              Hepatitis C
# 748                    0                  0             Hypoglycemia
# 2019                   0                  0                     Acne
#
# [1476 rows x 83 columns]

# %%
test.shape
# Out:
# (1476, 83)

# %%
X_test=test.drop(['prognosis'],axis=1)
y_test=test['prognosis']

# %%
X_train=data.drop(['prognosis'],axis=1)
y_train=data['prognosis']

# %%
y_test
# Out:
# 2530       Heart attack
# 2981       Heart attack
# 1114       Heart attack
# 1939       Heart attack
# 1932       Heart attack
#              ...
# 1160    Osteoarthristis
# 348     Osteoarthristis
# 3724    Osteoarthristis
# 3519    Osteoarthristis
# 4708    Osteoarthristis
# Name: prognosis, Length: 1476, dtype: object

# %%
from sklearn.naive_bayes import BernoulliNB    
from sklearn.metrics import accuracy_score,precision_score, recall_score,f1_score
import time
time1=time.time()

model=BernoulliNB()                         
model.fit(X_train,y_train)

y_pred=model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')                          # 因是多分類須加參數 'weighted' 
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print("伯努力貝氏分類:")
print("Accuracy :{}".format(accuracy))
print("Precision:{}".format(precision))
print("Recall   :{}".format(recall))
print("F1-Score :{}".format(f1))
time2=time.time()
time3=time2-time1
print(time3)
# Out:
# 伯努力貝氏分類:
# Accuracy :1.0
# Precision:1.0
# Recall   :1.0
# F1-Score :1.0
# 0.23766303062438965
